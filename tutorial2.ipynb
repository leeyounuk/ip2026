# %%
li = ['abc', 23, 4.34, 23]

# %%
li[1] = 45
print(li)
# Out:
# ['abc', 45, 4.34, 23]

# %%
t = (23 , 'abc', 4.56, (2,3), 'def')
t[2] = 3.14
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 t = (23 , 'abc', 4.56, (2,3), 'def')
# ----> 2 t[2] = 3.14
#
# TypeError: 'tuple' object does not support item assignment

# %%
li = [1, 11, 3, 4, 5]
li.append('a')
print(li)
# Out:
# [1, 11, 3, 4, 5, 'a']

# %%
li.insert(2, 'i')
print(li)
# Out:
# [1, 11, 'i', 3, 4, 5, 'a']

# %%
li.extend([9, 8, 7])
print(li)
li.append([9,8,7])
print(li)
# Out:
# [1, 11, 'i', 3, 4, 5, 'a', 9, 8, 7, 9, 8, 7]
# [1, 11, 'i', 3, 4, 5, 'a', 9, 8, 7, 9, 8, 7, [9, 8, 7]]

# %%
li = ['a', 'b', 'c', 'd']
li.index('b')
# Out:
# 1

# %%
li = ['a', 'b', 'c', 'd']
li.count('b')
# Out:
# 1

# %%
li = ['a', 'b', 'c', 'd']
li.remove('b')
print(li)
# Out:
# ['a', 'c', 'd']

# %%
li = [5, 2, 6, 8]
li.reverse()
print(li)
# Out:
# [8, 6, 2, 5]

# %%
li.sort()
print(li)
# Out:
# [2, 5, 6, 8]
