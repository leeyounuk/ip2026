# %%
import numpy as np
import cv2

# Read the image
img = cv2.imread('mnt.jpg')

# Convert to grayscale
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply binary threshold
ret, thresh = cv2.threshold(imgray, 127, 255, 0)

# Find contours (OpenCV 4+ returns 2 values)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Optional: Draw the contours on the original image to verify
cv2.drawContours(img, contours, -1, (0, 255, 0), 3)
cv2.imshow('Contours', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.drawContours(img, contours,-1, (0,255,0), 3)

# %%
img = cv2.drawContours(img, contours, 3, (0,255,0), 3)

# %%
cnt = contours[4]
img = cv2.drawContours(img, [cnt], 0, (0,255,0), 3)

# %%
# Assuming 'img' is an image you've already loaded or processed
# img = cv2.imread('test.jpg')

# Display the image in a window named 'image'
cv2.imshow('image', img)

# Wait infinitely until a key is pressed
cv2.waitKey(0)

# Clean up and close the window
cv2.destroyAllWindows()
